# %%
from os import listdir
from os.path import isfile, join
mypath='c:/Users/brandon/Documents/work/solar system/alldata'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles
# Out:
# ['alldata-20210307.csv',
#  'alldata-20210421.csv',
#  'alldata-20210422.csv',
#  'alldata-20210423.csv',
#  'alldata-20210424.csv',
#  'alldata-20210425.csv',
#  'alldata-20210426.csv',
#  'alldata-20210427.csv',
#  'alldata-20210428.csv',
#  'alldata-20210429.csv',
#  'alldata-20210430.csv',
#  'alldata-20210501.csv',
#  'alldata-20210502.csv',
#  'alldata-20210503.csv',
#  'alldata-20210504.csv',
#  'alldata-20210505.csv',
#  'alldata-20210506.csv',
#  'alldata-20210507.csv',
#  'alldata-20210508.csv',
#  'alldata-20210509.csv',
#  'alldata-20210510.csv',
#  'alldata-20210511.csv',
#  'alldata-20210512.csv',
#  'alldata-20210513.csv',
#  'alldata-20210514.csv',
#  'alldata-20210515.csv',
#  'alldata-20210516.csv',
#  'alldata-20210517.csv',
#  'alldata-20210518.csv',
#  'alldata-20210519.csv',
#  'alldata-20210520.csv',
#  'alldata-20210521.csv',
#  'alldata-20210522.csv',
#  'alldata-20210523.csv',
#  'alldata-20210524.csv',
#  'alldata-20210525.csv',
#  'alldata-20210526.csv',
# ...

# %%
import os
import pandas as pd

path = os.path.join('c:' + os.sep, 'Users', 'brandon', 'Documents', 'work','solar system','alldata','alldata-20210423.csv')
student_data = pd.read_csv(path)
# student_data.dropna(how='all', axis=1, inplace=True)

student_data
# Out:
#         id            record_time  Vpv  Chg_cur  Chg_power  acc_kWh_hi  \
# 0    78969  23/4/2021 12:01:03 AM  0.0      NaN          0        1000
# 1    78970  23/4/2021 12:11:12 AM  0.0      NaN          0        1000
# 2    78971  23/4/2021 12:21:21 AM  0.0      NaN          0        1000
# 3    78972  23/4/2021 12:31:30 AM  0.0      NaN          0        1000
# 4    78973  23/4/2021 12:41:39 AM  0.0      NaN          0        1000
# ..     ...                    ...  ...      ...        ...         ...
# 137  79106  23/4/2021 11:12:16 PM  0.0      NaN          0        1000
# 138  79107  23/4/2021 11:22:25 PM  0.0      NaN          0        1000
# 139  79108  23/4/2021 11:32:34 PM  0.0      NaN          0        1000
# 140  79109  23/4/2021 11:42:43 PM  0.0      NaN          0        1000
# 141  79110  23/4/2021 11:52:52 PM  0.0      NaN          0        1000
#
#      acc_kWh_lo  acc_kWh_Total  acc_kWh_Today  Chg_status  ...  DICH8  DICH9  \
# ...
